# %%
from glob import glob
from pandas import DataFrame
import seaborn as sns; sns.set()

# %%
# %matplotlib inline

# %%
df_q3 = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba_times_mcc_q3.csv")
df_qh = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba_times_mcc_qh_not_NaN.csv")
df_qe = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba_times_mcc_qe_not_NaN.csv")
df_qc = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba_times_mcc_qc_not_NaN.csv")

# %%
df_q3.median()
# Out:
#  CONSENSUS    0.661479
#  DSSP         0.605096
#  STRIDE       0.603448
#  KAKSI        0.590909
#  PROSS        0.607595
# dtype: float64

# %%
df_q3.mean()
# Out:
#  CONSENSUS    0.658593
#  DSSP         0.602949
#  STRIDE       0.600058
#  KAKSI        0.589378
#  PROSS        0.605086
# dtype: float64

# %%
df_q3.std()
# Out:
#  CONSENSUS    0.073018
#  DSSP         0.069018
#  STRIDE       0.070804
#  KAKSI        0.066956
#  PROSS        0.067946
# dtype: float64

# %%
fig_q3 = sns.boxplot(data=df_q3)
fig_q3.set(xlabel='Método de atribuição', ylabel='Acurácia (Q3)',title="Distribuição acurácia (Q3) do CA (CBA x MCC) por proteína")
fig_q3.figure.savefig("../figures/ca_cba_times_mcc_q3.pdf")

# %%
df_qh.mean()
# Out:
#  CONSENSUS    0.712822
#  DSSP         0.670749
#  STRIDE       0.666290
#  KAKSI        0.648909
#  PROSS        0.700797
# dtype: float64

# %%
fig_qh = sns.boxplot(data=df_qh)
fig_qh.set(xlabel='Método de atribuição', ylabel='Acurácia (Qh)',title="Distribuição acurácia (Qh) do CA (CBA x MCC) por proteína")
fig_qh.figure.savefig("../figures/ca_cba_times_mcc_qh.pdf")

# %%
df_qe.mean()
# Out:
#  CONSENSUS    0.508486
#  DSSP         0.437331
#  STRIDE       0.431474
#  KAKSI        0.417782
#  PROSS        0.453560
# dtype: float64

# %%
fig_qe = sns.boxplot(data=df_qe)
fig_qe.set(xlabel='Método de atribuição', ylabel='Acurácia (Qe)',title="Distribuição acurácia (Qe) do CA (CBA x MCC) por proteína")
fig_qe.figure.savefig("../figures/ca_cba_times_mcc_qe.pdf")

# %%
df_qc.mean()
# Out:
#  CONSENSUS    0.687292
#  DSSP         0.635810
#  STRIDE       0.638957
#  KAKSI        0.637459
#  PROSS        0.606772
# dtype: float64

# %%
fig_qc = sns.boxplot(data=df_qc)
fig_qc.set(xlabel='Método de atribuição', ylabel='Acurácia (Qc)',title="Distribuição acurácia (Qc) do CA (CBA x MCC) por proteína")
fig_qc.figure.savefig("../figures/ca_cba_times_mcc_qc.pdf")
