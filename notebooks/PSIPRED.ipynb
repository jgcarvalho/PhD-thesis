# %%
from glob import glob
from pandas import DataFrame
import seaborn as sns; sns.set()

# %%
# %matplotlib inline

# %%
df_q3 = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/psipred_results_q3.csv")
df_qh = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/psipred_results_qh_not_NaN.csv")
df_qe = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/psipred_results_qe_not_NaN.csv")
df_qc = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/psipred_results_qc_not_NaN.csv")

# %%
df_q3.median()
# Out:
#  CONSENSUS    0.930556
#  DSSP         0.866953
#  STRIDE       0.858333
#  KAKSI        0.812500
#  PROSS        0.823458
# dtype: float64

# %%
df_q3.mean()
# Out:
#  CONSENSUS    0.921803
#  DSSP         0.861760
#  STRIDE       0.852687
#  KAKSI        0.808314
#  PROSS        0.819818
# dtype: float64

# %%
df_q3.std()
# Out:
#  CONSENSUS    0.051501
#  DSSP         0.059625
#  STRIDE       0.061026
#  KAKSI        0.053781
#  PROSS        0.059475
# dtype: float64

# %%
fig_q3 = sns.boxplot(data=df_q3)
fig_q3.set(xlabel='Método de atribuição', ylabel='Acurácia (Q3)',title="Distribuição acurácia (Q3) do PSIPRED por proteína")
fig_q3.figure.savefig("../figures/psipred_q3.pdf")

# %%
df_qh.mean()
# Out:
#  CONSENSUS    0.921346
#  DSSP         0.861077
#  STRIDE       0.847284
#  KAKSI        0.802295
#  PROSS        0.903122
# dtype: float64

# %%
fig_qh = sns.boxplot(data=df_qh)
fig_qh.set(xlabel='Método de atribuição', ylabel='Acurácia (Qh)',title="Distribuição acurácia (Qh) do PSIPRED por proteína")
fig_qh.figure.savefig("../figures/psipred_qh.pdf")

# %%
df_qe.mean()
# Out:
#  CONSENSUS    0.876759
#  DSSP         0.805316
#  STRIDE       0.790436
#  KAKSI        0.738280
#  PROSS        0.752929
# dtype: float64

# %%
fig_qe = sns.boxplot(data=df_qe)
fig_qe.set(xlabel='Método de atribuição', ylabel='Acurácia (Qe)',title="Distribuição acurácia (Qe) do PSIPRED por proteína")
fig_qe.figure.savefig("../figures/psipred_qe.pdf")

# %%
df_qc.mean()
# Out:
#  CONSENSUS    0.916518
#  DSSP         0.862282
#  STRIDE       0.864364
#  KAKSI        0.823916
#  PROSS        0.768455
# dtype: float64

# %%
fig_qc = sns.boxplot(data=df_qc)
fig_qc.set(xlabel='Método de atribuição', ylabel='Acurácia (Qc)',title="Distribuição acurácia (Qc) do PSIPRED por proteína")
fig_qc.figure.savefig("../figures/psipred_qc.pdf")
