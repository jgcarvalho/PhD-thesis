# %%
from glob import glob
from pandas import DataFrame
import seaborn as sns; sns.set()

# %%
# %matplotlib inline

# %%
df_q3 = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba2_times_mcc_q3.csv")
df_qh = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba2_times_mcc_qh_not_NaN.csv")
df_qe = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba2_times_mcc_qe_not_NaN.csv")
df_qc = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba2_times_mcc_qc_not_NaN.csv")

# %%
df_q3.median()
# Out:
#  CONSENSUS    0.670940
#  DSSP         0.615120
#  STRIDE       0.613569
#  KAKSI        0.599398
#  PROSS        0.614754
# dtype: float64

# %%
df_q3.mean()
# Out:
#  CONSENSUS    0.667354
#  DSSP         0.612574
#  STRIDE       0.609640
#  KAKSI        0.597538
#  PROSS        0.612318
# dtype: float64

# %%
df_q3.std()
# Out:
#  CONSENSUS    0.075048
#  DSSP         0.070516
#  STRIDE       0.072288
#  KAKSI        0.067778
#  PROSS        0.069830
# dtype: float64

# %%
fig_q3 = sns.boxplot(data=df_q3)
fig_q3.set(xlabel='Método de atribuição', ylabel='Acurácia (Q3)',title="Distribuição acurácia (Q3) do CA (CBA² x MCC) por proteína")
fig_q3.figure.savefig("../figures/ca_cba2_times_mcc_q3.pdf")

# %%
df_qh.mean()
# Out:
#  CONSENSUS    0.728673
#  DSSP         0.685044
#  STRIDE       0.680049
#  KAKSI        0.663385
#  PROSS        0.715903
# dtype: float64

# %%
fig_qh = sns.boxplot(data=df_qh)
fig_qh.set(xlabel='Método de atribuição', ylabel='Acurácia (Qh)',title="Distribuição acurácia (Qh) do CA (CBA² x MCC) por proteína")
fig_qh.figure.savefig("../figures/ca_cba2_times_mcc_qh.pdf")

# %%
df_qe.mean()
# Out:
#  CONSENSUS    0.530664
#  DSSP         0.458841
#  STRIDE       0.452972
#  KAKSI        0.436730
#  PROSS        0.472156
# dtype: float64

# %%
fig_qe = sns.boxplot(data=df_qe)
fig_qe.set(xlabel='Método de atribuição', ylabel='Acurácia (Qe)',title="Distribuição acurácia (Qe) do CA (CBA² x MCC) por proteína")
fig_qe.figure.savefig("../figures/ca_cba2_times_mcc_qe.pdf")

# %%
df_qc.mean()
# Out:
#  CONSENSUS    0.686860
#  DSSP         0.634184
#  STRIDE       0.637257
#  KAKSI        0.634124
#  PROSS        0.603698
# dtype: float64

# %%
fig_qc = sns.boxplot(data=df_qc)
fig_qc.set(xlabel='Método de atribuição', ylabel='Acurácia (Qc)',title="Distribuição acurácia (Qc) do CA (CBA² x MCC) por proteína")
fig_qc.figure.savefig("../figures/ca_cba2_times_mcc_qc.pdf")
