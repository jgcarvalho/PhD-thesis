# %%
from glob import glob
from pandas import DataFrame
import seaborn as sns; sns.set()

# %%
# %matplotlib inline

# %%
df_q3 = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/psipred_results_q3.csv")
df_qh = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/psipred_results_qh.csv")

# %%
fig_q3 = sns.boxplot(data=df_q3)

# %%
fig_qh = sns.boxplot(data=df_qh)
