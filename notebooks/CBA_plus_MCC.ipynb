# %%
from glob import glob
from pandas import DataFrame
import seaborn as sns; sns.set()

# %%
# %matplotlib inline

# %%
df_q3 = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba_plus_mcc_q3.csv")
df_qh = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba_plus_mcc_qh_not_NaN.csv")
df_qe = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba_plus_mcc_qe_not_NaN.csv")
df_qc = DataFrame.from_csv("/home/jgcarvalho/Documents/PhD-thesis/notebooks/pred_cba_plus_mcc_qc_not_NaN.csv")

# %%
df_q3.median()
# Out:
#  CONSENSUS    0.668605
#  DSSP         0.612245
#  STRIDE       0.610354
#  KAKSI        0.597484
#  PROSS        0.612637
# dtype: float64

# %%
df_q3.mean()
# Out:
#  CONSENSUS    0.665101
#  DSSP         0.609799
#  STRIDE       0.606935
#  KAKSI        0.595790
#  PROSS        0.610042
# dtype: float64

# %%
df_q3.std()
# Out:
#  CONSENSUS    0.072954
#  DSSP         0.067514
#  STRIDE       0.068908
#  KAKSI        0.065335
#  PROSS        0.067687
# dtype: float64

# %%
fig_q3 = sns.boxplot(data=df_q3)
fig_q3.set(xlabel='Método de atribuição', ylabel='Acurácia (Q3)',title="Distribuição acurácia (Q3) CA (CBA + MCC) por proteína")
fig_q3.figure.savefig("../figures/ca_cba_plus_mcc_q3.pdf")

# %%
df_qh.mean()
# Out:
#  CONSENSUS    0.711396
#  DSSP         0.668690
#  STRIDE       0.664173
#  KAKSI        0.647642
#  PROSS        0.698964
# dtype: float64

# %%
fig_qh = sns.boxplot(data=df_qh)
fig_qh.set(xlabel='Método de atribuição', ylabel='Acurácia (Qh)',title="Distribuição acurácia (Qh) do CA (CBA + MCC) por proteína")
fig_qh.figure.savefig("../figures/ca_cba_plus_mcc_qh.pdf")

# %%
df_qe.mean()
# Out:
#  CONSENSUS    0.563289
#  DSSP         0.486156
#  STRIDE       0.479493
#  KAKSI        0.464297
#  PROSS        0.501259
# dtype: float64

# %%
fig_qe = sns.boxplot(data=df_qe)
fig_qe.set(xlabel='Método de atribuição', ylabel='Acurácia (Qe)',title="Distribuição acurácia (Qe) do CA (CBA + MCC) por proteína")
fig_qe.figure.savefig("../figures/ca_cba_plus_mcc_qe.pdf")

# %%
df_qc.mean()
# Out:
#  CONSENSUS    0.678938
#  DSSP         0.626946
#  STRIDE       0.630233
#  KAKSI        0.628469
#  PROSS        0.597618
# dtype: float64

# %%
fig_qc = sns.boxplot(data=df_qc)
fig_qc.set(xlabel='Método de atribuição', ylabel='Acurácia (Qc)',title="Distribuição acurácia (Qc) do CA (CBA + MCC) por proteína")
fig_qc.figure.savefig("../figures/ca_cba_plus_mcc_qc.pdf")
